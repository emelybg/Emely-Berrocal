# %% [markdown]
# <img src="CAR.jpg" alt="Italian Trulli"/>

# %% [markdown]
# <center> <h1 Style="color:#FF7F50">Analisis de datos</h1> </center>
# <center> <h5 Style="color:#FF7F50">Emely Berrocal</h5> </center>
# <center> <h5 Style="color:#FF7F50">Universidad Castro Carazo</h5> </center>
# <center> <h5 Style="color:#FF7F50"> I C - 2023</h5> </center>

# %% [markdown]
# <p Style="text-align: justify">Este notebook contiene el analisis de los datos de los vehiculos a la venta por parte de la empresa Pk2, esta empresa se encuentra interesada en responder una pregunta de negocio particular.
#     Como se puede incrementar las ventas de autos de segunda mano?
#     Para esto se realiza un analisis del conjunto de datos facilitado por la empresa a efectos de poder brindar conocimiento sobre las ditribuciones de sus lotes de venta, los autos con mayor precio, o caracteristicas de los autos, esto para dotar de insumos suficientes a la toma de desiciones</p>
# </br>
# <a href="https://archive.ics.uci.edu/ml/datasets/Automobile"> fuente de datos para el proceso de analisis </a>

# %% [markdown]
# <h2 Style = "color:#DC143C">1.Cargar y estandarizar los set de datos</h2>
# </br>
# <p> que se hace en esta estapa? </p>
# </br>
# <ol>
#   <li>importar las librerias de python necesarias</li>
#   <li>Importar el o los set de datos</li>
#   <li>revisar los encabezados de los dataframes </li>
#   <li>Si solo si tenemos mas de 1 set de dstos,los vamos a unir en uno solo </li>
# </ol>
#   <h3 Style = "color:#DC143C"> importar las librerias de python necesarias </h3>

# %%
import pandas as pd #Se Usa para el manejo de grandes volumnes de datos-Dataframe
import  numpy as np #Se Usa para el manejo de estructuras de datos: Tumplas,listas,Diccionario
import matplotlib as mpl
import matplotlib.pyplot as plt #permite crear graficos.

# %%
mpl.rcParams["axes.spines.bottom"] = True
mpl.rcParams["axes.spines.left"] = False
mpl.rcParams["axes.spines.right"] = True
mpl.rcParams["axes.spines.top"] = False

# %% [markdown]
# <h3 Style = "color:#C71585">1.2 importar los set de datos</h3>

# %%
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors",
       "style", "wheels", "engine", "base", "length", "width", "heingt",
       "curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
       "compression", "horsepower", "peak", "City", "Higway", "price"]
df_1er_set = pd.read_csv("autos.csv" , names=cols)
df_2do_set = pd.read_csv("Autos1.csv" , names=cols)

# %%
df_1er_set.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
# 3        102  5500   24     30  13950
# 4        115  5500   18     22  17450
#
# [5 rows x 26 columns]

# %%
df_1er_set.shape
# Out:
# (197, 26)

# %%
df_1er_set.tail (5)
# Out:
#      symboling normalized        make    fuel aspiration doors  style wheels  \
# 192          0          ?  volkswagen  diesel      turbo  four  sedan    fwd
# 193          0          ?  volkswagen     gas        std  four  wagon    fwd
# 194         -2        103       volvo     gas        std  four  sedan    rwd
# 195         -1         74       volvo     gas        std  four  wagon    rwd
# 196         -2        103       volvo     gas        std  four  sedan    rwd
#
#     engine   base  ...  engine-size  system  bore  stroke compression  \
# 192  front  100.4  ...           97     idi  3.01    3.40        23.0
# 193  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 194  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 195  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 196  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 192         68  4500   33     38  13845
# 193         88  5500   25     31  12290
# 194        114  5400   23     28  12940
# 195        114  5400   23     28  13415
# 196        114  5400   24     28  15985
#
# [5 rows x 26 columns]

# %%
df_1er_set.describe
# Out:
# <bound method NDFrame.describe of      symboling normalized         make    fuel aspiration doors        style  \
# 0            3          ?  alfa-romero     gas        std   two  convertible
# 1            3          ?  alfa-romero     gas        std   two  convertible
# 2            1          ?  alfa-romero     gas        std   two    hatchback
# 3            2        164         audi     gas        std  four        sedan
# 4            2        164         audi     gas        std  four        sedan
# ..         ...        ...          ...     ...        ...   ...          ...
# 192          0          ?   volkswagen  diesel      turbo  four        sedan
# 193          0          ?   volkswagen     gas        std  four        wagon
# 194         -2        103        volvo     gas        std  four        sedan
# 195         -1         74        volvo     gas        std  four        wagon
# 196         -2        103        volvo     gas        std  four        sedan
#
#     wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# 0      rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# 1      rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# 2      rwd  front   94.5  ...          152    mpfi  2.68    3.47         9.0
# 3      fwd  front   99.8  ...          109    mpfi  3.19    3.40        10.0
# 4      4wd  front   99.4  ...          136    mpfi  3.19    3.40         8.0
# ..     ...    ...    ...  ...          ...     ...   ...     ...         ...
# 192    fwd  front  100.4  ...           97     idi  3.01    3.40        23.0
# 193    fwd  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 194    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 195    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 196    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 0          111  5000   21     27  13495
# 1          111  5000   21     27  16500
# 2          154  5000   19     26  16500
# 3          102  5500   24     30  13950
# 4          115  5500   18     22  17450
# ..         ...   ...  ...    ...    ...
# 192         68  4500   33     38  13845
# 193         88  5500   25     31  12290
# 194        114  5400   23     28  12940
# 195        114  5400   23     28  13415
# 196        114  5400   24     28  15985
#
# [197 rows x 26 columns]>

# %%
df_1er_set.info
# Out:
# <bound method DataFrame.info of      symboling normalized         make    fuel aspiration doors        style  \
# 0            3          ?  alfa-romero     gas        std   two  convertible
# 1            3          ?  alfa-romero     gas        std   two  convertible
# 2            1          ?  alfa-romero     gas        std   two    hatchback
# 3            2        164         audi     gas        std  four        sedan
# 4            2        164         audi     gas        std  four        sedan
# ..         ...        ...          ...     ...        ...   ...          ...
# 192          0          ?   volkswagen  diesel      turbo  four        sedan
# 193          0          ?   volkswagen     gas        std  four        wagon
# 194         -2        103        volvo     gas        std  four        sedan
# 195         -1         74        volvo     gas        std  four        wagon
# 196         -2        103        volvo     gas        std  four        sedan
#
#     wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# 0      rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# 1      rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# 2      rwd  front   94.5  ...          152    mpfi  2.68    3.47         9.0
# 3      fwd  front   99.8  ...          109    mpfi  3.19    3.40        10.0
# 4      4wd  front   99.4  ...          136    mpfi  3.19    3.40         8.0
# ..     ...    ...    ...  ...          ...     ...   ...     ...         ...
# 192    fwd  front  100.4  ...           97     idi  3.01    3.40        23.0
# 193    fwd  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 194    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 195    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 196    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 0          111  5000   21     27  13495
# 1          111  5000   21     27  16500
# 2          154  5000   19     26  16500
# 3          102  5500   24     30  13950
# 4          115  5500   18     22  17450
# ..         ...   ...  ...    ...    ...
# 192         68  4500   33     38  13845
# 193         88  5500   25     31  12290
# 194        114  5400   23     28  12940
# 195        114  5400   23     28  13415
# 196        114  5400   24     28  15985
#
# [197 rows x 26 columns]>

# %% [markdown]
# <h2 Style="color:#9370DB"> 1.3. Revisar los encabezados de los DataFrame </h2>
# <p> Se motiva la estandarizacion de los nombres de las columnas, considerando lo siguiente
# </p>
# <ol>
# <l1> Los nombres de las columnas no deben tener espacios en blanco</li>
# <li> los nombres no deben empezar por numero </li>
# <li> Si el nomnre se conforma por 2 o mas palabras la letra inicial de cada palabra va en mayuscula </li>
# <li> No debe existir nombres repetidos </li>
# </ol>

# %%
df_1er_set.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_2do_set.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_1er_set.rename({"engine-size" : "engineSize"}, axis=1, inplace=True)
df_2do_set.rename({"engine-size" : "engineSize"}, axis=1, inplace=True)
df_1er_set.head(2)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
#
# [2 rows x 26 columns]

# %%
df_2do_set.head (2)
# Out:
#    symboling normalized    make fuel aspiration doors      style wheels  \
# 0          2        134  toyota  gas        std   two    hardtop    rwd
# 1          2        134  toyota  gas        std   two  hatchback    rwd
#
#   engine  base  ...  engineSize  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
#
#    peak City  Higway  price
# 0  4800   24      30   9639
# 1  4800   24      30   9989
#
# [2 rows x 26 columns]

# %% [markdown]
# <h3 Style = "color:=696969">1.4 Unir los set de datos </h3>

# %%
unionArchivos = [df_1er_set, df_2do_set]
dfAutos = pd.concat(unionArchivos)
dfAutos.shape
# Out:
# (226, 26)

# %%
dfAutos.head(3)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
#
# [3 rows x 26 columns]

# %% [markdown]
# <h2 Style = "color:#DC143C">2.Manejo de los valores faltantes o perdidos</h2>
# </br>
# <p> que se hace en esta estapa? </p>
# </br>
# <ol>
#   <li>Identificar como se muestran los valores faltantes y estandarizarlosa NaN</li>
#   <li>Contar la cantidad de valores faltantes por variable</li>
#   <li>Analizar la imputacion de valores numericos (con la media) </li>
#   <li>Analizar la imputacion de valores categoricos(con valor mas frecuente) </li>
#   <li> Eliminar filas con valores faltantes </li>
# </ol>
#   <h3 Style = "color:#DC143C"> 2.1 Identificar como se muestran los valores faltantes</h3>

# %%
dfAutos
# Out:
#     symboling normalized         make    fuel aspiration doors        style  \
# 0           3          ?  alfa-romero     gas        std   two  convertible
# 1           3          ?  alfa-romero     gas        std   two  convertible
# 2           1          ?  alfa-romero     gas        std   two    hatchback
# 3           2        164         audi     gas        std  four        sedan
# 4           2        164         audi     gas        std  four        sedan
# ..        ...        ...          ...     ...        ...   ...          ...
# 24          0          ?   volkswagen  diesel      turbo  four        sedan
# 25          0          ?   volkswagen     gas        std  four        wagon
# 26         -2        103        volvo     gas        std  four        sedan
# 27         -1         74        volvo     gas        std  four        wagon
# 28         -2        103        volvo     gas        std  four        sedan
#
#    wheels engine   base  ...  engineSize  system  bore  stroke compression  \
# 0     rwd  front   88.6  ...         130    mpfi  3.47    2.68         9.0
# 1     rwd  front   88.6  ...         130    mpfi  3.47    2.68         9.0
# 2     rwd  front   94.5  ...         152    mpfi  2.68    3.47         9.0
# 3     fwd  front   99.8  ...         109    mpfi  3.19    3.40        10.0
# 4     4wd  front   99.4  ...         136    mpfi  3.19    3.40         8.0
# ..    ...    ...    ...  ...         ...     ...   ...     ...         ...
# 24    fwd  front  100.4  ...          97     idi  3.01     3.4        23.0
# 25    fwd  front  100.4  ...         109    mpfi  3.19     3.4         9.0
# 26    rwd  front  104.3  ...         141    mpfi  3.78    3.15         9.5
# 27    rwd  front  104.3  ...         141    mpfi  3.78    3.15         9.5
# 28    rwd  front  104.3  ...         141    mpfi  3.78    3.15         9.5
#
#    horsepower  peak City Higway  price
# 0         111  5000   21     27  13495
# 1         111  5000   21     27  16500
# 2         154  5000   19     26  16500
# 3         102  5500   24     30  13950
# 4         115  5500   18     22  17450
# ..        ...   ...  ...    ...    ...
# 24         68  4500   33     38  13845
# 25         88  5500   25     31  12290
# 26        114  5400   23     28  12940
# 27        114  5400   23     28  13415
# 28        114  5400   24     28  15985
#
# [226 rows x 26 columns]

# %%
dfAutos.replace("?" , np.nan, inplace=True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
# 3        102  5500   24     30  13950
# 4        115  5500   18     22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# <h3 Style ="color696969">2.2) Contar la cantidad de valores faltantes por variable</h3>

# %%
dfValoresFaltantes=dfAutos.isnull()
dfValoresFaltantes.head(3)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False        True  False  False       False  False  False   False
# 1      False        True  False  False       False  False  False   False
# 2      False        True  False  False       False  False  False   False
#
#    engine   base  ...  engineSize  system   bore  stroke  compression  \
# 0   False  False  ...       False   False  False   False        False
# 1   False  False  ...       False   False  False   False        False
# 2   False  False  ...       False   False  False   False        False
#
#    horsepower   peak   City  Higway  price
# 0       False  False  False   False  False
# 1       False  False  False   False  False
# 2       False  False  False   False  False
#
# [3 rows x 26 columns]

# %%
for column in dfValoresFaltantes.columns.values.tolist():
    print (column)
    print(dfValoresFaltantes[column].value_counts())
    print ("")
# Out:
# symboling
# False    226
# Name: symboling, dtype: int64
#
# normalized
# False    180
# True      46
# Name: normalized, dtype: int64
#
# make
# False    226
# Name: make, dtype: int64
#
# fuel
# False    226
# Name: fuel, dtype: int64
#
# aspiration
# False    226
# Name: aspiration, dtype: int64
#
# doors
# False    224
# True       2
# Name: doors, dtype: int64
#
# style
# False    226
# Name: style, dtype: int64
#
# wheels
# False    226
# Name: wheels, dtype: int64
#
# engine
# False    226
# Name: engine, dtype: int64
#
# base
# False    226
# Name: base, dtype: int64
#
# length
# False    226
# Name: length, dtype: int64
#
# width
# False    226
# Name: width, dtype: int64
#
# heingt
# False    226
# Name: heingt, dtype: int64
#
# curb
# False    226
# Name: curb, dtype: int64
#
# engineType
# False    226
# Name: engineType, dtype: int64
#
# Cylinders
# False    226
# Name: Cylinders, dtype: int64
#
# engineSize
# False    226
# Name: engineSize, dtype: int64
#
# system
# False    226
# Name: system, dtype: int64
#
# bore
# False    222
# True       4
# Name: bore, dtype: int64
#
# stroke
# False    222
# True       4
# Name: stroke, dtype: int64
#
# compression
# False    226
# Name: compression, dtype: int64
#
# horsepower
# False    224
# True       2
# Name: horsepower, dtype: int64
#
# peak
# False    224
# True       2
# Name: peak, dtype: int64
#
# City
# False    226
# Name: City, dtype: int64
#
# Higway
# False    226
# Name: Higway, dtype: int64
#
# price
# False    222
# True       4
# Name: price, dtype: int64

# %% [markdown]
# <h3 Style ="color696969">2.3) Analizar la imputacion de valores numericos</h3>

# %%
mean_value = dfAutos["normalized"].astype("float").mean(axis=0)
print("La media de normalized es:", mean_value)
# Out:
# La media de normalized es: 122.28333333333333

# %%
mean_value = dfAutos["bore"].astype("float").mean(axis=0)
print("La media de normalized es:", mean_value)
# Out:
# La media de normalized es: 3.3194594594594586

# %%
mean_value = dfAutos["stroke"].astype("float").mean(axis=0)
print("La media de normalized es:", mean_value)
# Out:
# La media de normalized es: 3.2785135135135133

# %%
mean_value = dfAutos["horsepower"].astype("float").mean(axis=0)
print("La media de normalized es:", mean_value)
# Out:
# La media de normalized es: 102.98214285714286

# %%
mean_value = dfAutos["peak"].astype("float").mean(axis=0)
print("La media de normalized es:", mean_value)
# Out:
# La media de normalized es: 5100.892857142857

# %%
dfAutos ["normalized"].replace(np.nan, 122, inplace=True)
dfAutos ["bore"].replace(np.nan, 3.31, inplace=True)
dfAutos ["stroke"].replace(np.nan, 3.27, inplace=True)
dfAutos ["horsepower"].replace(np.nan, 102, inplace=True)
dfAutos ["peak"].replace(np.nan, 5100, inplace=True)
dfAutos.head(3)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
#
# [3 rows x 26 columns]

# %% [markdown]
# <h3 Style ="color696969">2.4) Analizar la imputacion de valores caracter con el dato mas frecuente</h3>

# %%
dfAutos["doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
dfAutos["doors"].replace(np.nan, "four", inplace=True)
dfAutos.head(2)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
#
# [2 rows x 26 columns]

# %% [markdown]
# <h3 Style ="color696969">2.5) Eliminar filas con valores faltantes</h3>

# %%
dfAutos.dropna(subset=["price"], axis=0, inplace=True)
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfValoresFaltantes=dfAutos.isnull()
for column in dfValoresFaltantes.columns.values.tolist():
    print (column)
    print (dfValoresFaltantes[column].value_counts())
    print (" ")
# Out:
# symboling
# False    222
# Name: symboling, dtype: int64
#
# normalized
# False    222
# Name: normalized, dtype: int64
#
# make
# False    222
# Name: make, dtype: int64
#
# fuel
# False    222
# Name: fuel, dtype: int64
#
# aspiration
# False    222
# Name: aspiration, dtype: int64
#
# doors
# False    222
# Name: doors, dtype: int64
#
# style
# False    222
# Name: style, dtype: int64
#
# wheels
# False    222
# Name: wheels, dtype: int64
#
# engine
# False    222
# Name: engine, dtype: int64
#
# base
# False    222
# Name: base, dtype: int64
#
# length
# False    222
# Name: length, dtype: int64
#
# width
# False    222
# Name: width, dtype: int64
#
# heingt
# False    222
# Name: heingt, dtype: int64
#
# curb
# False    222
# Name: curb, dtype: int64
#
# engineType
# False    222
# Name: engineType, dtype: int64
#
# Cylinders
# False    222
# Name: Cylinders, dtype: int64
#
# engineSize
# False    222
# Name: engineSize, dtype: int64
#
# system
# False    222
# Name: system, dtype: int64
#
# bore
# False    222
# Name: bore, dtype: int64
#
# stroke
# False    222
# Name: stroke, dtype: int64
#
# compression
# False    222
# Name: compression, dtype: int64
#
# horsepower
# False    222
# Name: horsepower, dtype: int64
#
# peak
# False    222
# Name: peak, dtype: int64
#
# City
# False    222
# Name: City, dtype: int64
#
# Higway
# False    222
# Name: Higway, dtype: int64
#
# price
# False    222
# Name: price, dtype: int64

# %% [markdown]
# <h2 Style = "color:#DC143C">3.Estandarizacion de los datos</h2>
# </br>
# <p> que se hace en esta estapa? </p>
# </br>
# <ol>
#   <li>Verificar el dominio de cada variable y se ajusta si es necesario</li>
#   <li>Se convierten los valores en funcion de su interpretacion</li>
#   <li> Se Normalizan los datos para que los valores queden entre 0 y 1 </li>
#   <li> Binnig crear categorias para el resumen de datos</li>
# </ol>
#   <h3 Style = "color:#DC143C"> 3.1 Verificar los dominios de variables</h3>

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
# 3        102  5500   24     30  13950
# 4        115  5500   18     22  17450
#
# [5 rows x 26 columns]

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engineSize       int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# City             int64
# Higway           int64
# price           object
# dtype: object

# %%
dfAutos[["normalized"]] = dfAutos[["normalized"]].astype("int")
dfAutos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engineSize       int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# City             int64
# Higway           int64
# price           object
# dtype: object

# %%
dfAutos[["bore", "stroke", "peak", "price"]] = dfAutos[["bore", "stroke", "peak", "price"]].astype("float")
dfAutos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engineSize       int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower      object
# peak           float64
# City             int64
# Higway           int64
# price          float64
# dtype: object

# %%
dfAutos[["horsepower"]] = dfAutos[["horsepower"]].astype("int")
dfAutos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engineSize       int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower       int32
# peak           float64
# City             int64
# Higway           int64
# price          float64
# dtype: object

# %% [markdown]
#   <h3 Style = "color:#DC143C"> 3.2 Convertir los valores en funcion de su interpretacion</h3>

# %%
dfAutos.head(3)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
#
#   horsepower    peak City  Higway    price
# 0        111  5000.0   21      27  13495.0
# 1        111  5000.0   21      27  16500.0
# 2        154  5000.0   19      26  16500.0
#
# [3 rows x 26 columns]

# %%
dfAutos["City L/100km"] = 235/dfAutos["City"]
dfAutos.head(3)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  system  bore  stroke  compression horsepower  \
# 0    rwd  front  88.6  ...    mpfi  3.47    2.68          9.0        111
# 1    rwd  front  88.6  ...    mpfi  3.47    2.68          9.0        111
# 2    rwd  front  94.5  ...    mpfi  2.68    3.47          9.0        154
#
#      peak  City Higway    price  City L/100km
# 0  5000.0    21     27  13495.0     11.190476
# 1  5000.0    21     27  16500.0     11.190476
# 2  5000.0    19     26  16500.0     12.368421
#
# [3 rows x 27 columns]

# %%
dfAutos["Higway L/100km"] = 235/dfAutos["Higway"]
dfAutos.head(3)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower    peak  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000.0
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000.0
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000.0
#
#   City  Higway    price  City L/100km  Higway L/100km
# 0   21      27  13495.0     11.190476        8.703704
# 1   21      27  16500.0     11.190476        8.703704
# 2   19      26  16500.0     12.368421        9.038462
#
# [3 rows x 28 columns]

# %% [markdown]
#   <h3 Style = "color:#DC143C"> 3.3 Se normalizan los datos para que los valores queden entre 0 y 1</h3>

# %%
dfAutos.head(4)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower    peak  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000.0
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000.0
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000.0
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500.0
#
#   City  Higway    price  City L/100km  Higway L/100km
# 0   21      27  13495.0     11.190476        8.703704
# 1   21      27  16500.0     11.190476        8.703704
# 2   19      26  16500.0     12.368421        9.038462
# 3   24      30  13950.0      9.791667        7.833333
#
# [4 rows x 28 columns]

# %%
dfTemp = dfAutos [["length", "width", "heingt"]]
dfTemp.head(5)
# Out:
#    length  width  heingt
# 0   168.8   64.1    48.8
# 1   168.8   64.1    48.8
# 2   171.2   65.5    52.4
# 3   176.6   66.2    54.3
# 4   176.6   66.4    54.3

# %%
dfAutos["lengthNorm"] = dfAutos["length"]/dfAutos["length"].max()
dfAutos["widthNorm"] = dfAutos["width"]/dfAutos["width"].max()
dfAutos["heingtNorm"] = dfAutos["heingt"]/dfAutos["heingt"].max()
dfTemp = dfAutos [["lengthNorm", "widthNorm", "heingtNorm"]]
dfTemp.head(5)
# Out:
#    lengthNorm  widthNorm  heingtNorm
# 0    0.811148   0.890278    0.816054
# 1    0.811148   0.890278    0.816054
# 2    0.822681   0.909722    0.876254
# 3    0.848630   0.919444    0.908027
# 4    0.848630   0.922222    0.908027

# %% [markdown]
#   <h3 Style = "color:#DC143C"> 3.4  Binning crear categorias para el resumen de datos</h3>

# %%
dfTemp = dfAutos [["horsepower"]]
dfTemp.head(5)
# Out:
#    horsepower
# 0         111
# 1         111
# 2         154
# 3         102
# 4         115

# %%
dfAutos.describe()
# Out:
#         symboling  normalized        base      length       width      heingt  \
# count  222.000000  222.000000  222.000000  222.000000  222.000000  222.000000
# mean     0.909910  122.229730   98.661261  174.064865   65.836036   53.766667
# std      1.280198   33.651614    5.648067   11.720591    1.970382    2.367974
# min     -2.000000   65.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000  101.000000   94.500000  167.350000   64.200000   52.000000
# 50%      1.000000  122.000000   97.250000  173.200000   65.500000   54.100000
# 75%      2.000000  136.250000  102.300000  180.200000   66.500000   55.675000
# max      3.000000  256.000000  120.900000  208.100000   72.000000   59.800000
#
#               curb  engineSize        bore      stroke  ...  horsepower  \
# count   222.000000  222.000000  222.000000  222.000000  ...  222.000000
# mean   2540.418919  126.450450    3.319955    3.280090  ...  102.180180
# std     494.544729   40.226562    0.258981    0.305005  ...   36.334344
# min    1488.000000   61.000000    2.540000    2.070000  ...   48.000000
# 25%    2209.000000   98.000000    3.150000    3.150000  ...   70.000000
# 50%    2414.000000  115.000000    3.310000    3.350000  ...   95.000000
# 75%    2841.250000  146.000000    3.580000    3.447500  ...  116.000000
# max    4066.000000  326.000000    3.940000    4.170000  ...  262.000000
#
#               peak        City      Higway         price  City L/100km  \
# count   222.000000  222.000000  222.000000    222.000000    222.000000
# mean   5093.468468   25.445946   30.990991  12780.941441      9.803749
# std     481.973832    6.272417    6.701787   7530.446820      2.441520
# min    4150.000000   13.000000   16.000000   5118.000000      4.795918
# 25%    4800.000000   20.250000   25.000000   7898.000000      7.833333
# 50%    5100.000000   25.000000   30.000000  10221.500000      9.400000
# 75%    5500.000000   30.000000   34.000000  15628.750000     11.610119
# max    6600.000000   49.000000   54.000000  45400.000000     18.076923
#
#        Higway L/100km  lengthNorm   widthNorm  heingtNorm
# count      222.000000  222.000000  222.000000  222.000000
# mean         7.947735    0.836448    0.914389    0.899108
# std          1.783939    0.056322    0.027366    0.039598
# min          4.351852    0.678039    0.837500    0.799331
# 25%          6.911765    0.804181    0.891667    0.869565
# 50%          7.833333    0.832292    0.909722    0.904682
# 75%          9.400000    0.865930    0.923611    0.931020
# max         14.687500    1.000000    1.000000    1.000000
#
# [8 rows x 21 columns]

# %%
bins = np.linspace(min(dfAutos["horsepower"]), max (dfAutos["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
groupNames = ["Pequeño", "Mediano", "Grande"]
dfAutos["horsepowerBins"] = pd.cut(dfAutos["horsepower"], bins, labels=groupNames, include_lowest=True)
dfAutos[["horsepower", "horsepowerBins"]].head(5)
# Out:
#    horsepower horsepowerBins
# 0         111        Pequeño
# 1         111        Pequeño
# 2         154        Mediano
# 3         102        Pequeño
# 4         115        Pequeño

# %%
dfAutos["horsepowerBins"].value_counts()
# Out:
# Pequeño    174
# Mediano     43
# Grande       5
# Name: horsepowerBins, dtype: int64

# %% [markdown]
# %matplotlib inline
# import matplotlib as plt
# from matplotlib import pyplot
#
# plt.pyplot.hist(dfAutos["horsepowerBins"])
#
# plt.pyplot.xlabel("Caballos de fuerza")
# plt.pyplot.ylabel("Cantidad")
# plt.pyplot.title("Cantidad de carros segun los caballos de fuerza")

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...    peak  City  Higway    price City L/100km  \
# 0    rwd  front  88.6  ...  5000.0    21      27  13495.0    11.190476
# 1    rwd  front  88.6  ...  5000.0    21      27  16500.0    11.190476
# 2    rwd  front  94.5  ...  5000.0    19      26  16500.0    12.368421
# 3    fwd  front  99.8  ...  5500.0    24      30  13950.0     9.791667
# 4    4wd  front  99.4  ...  5500.0    18      22  17450.0    13.055556
#
#   Higway L/100km  lengthNorm widthNorm  heingtNorm  horsepowerBins
# 0       8.703704    0.811148  0.890278    0.816054         Pequeño
# 1       8.703704    0.811148  0.890278    0.816054         Pequeño
# 2       9.038462    0.822681  0.909722    0.876254         Mediano
# 3       7.833333    0.848630  0.919444    0.908027         Pequeño
# 4      10.681818    0.848630  0.922222    0.908027         Pequeño
#
# [5 rows x 32 columns]

# %% [markdown]
# <h2 Style = "color:#DC143C">4.Visualizacion de Datos</h2>
# </br>
# <p> En este apartado se van a crear diferentes visualizaciones (graficas), las cuales nis ayudan a realizar una interpretacion y analisis de la informacion del set </p>
# </br>
# <ol>
#   <li>Identificar las preguntas del negocio</li>
#   <li>Dar un formato/agrupar los datos para crear el grafico</li>
#   <li>Dar formato a los graficos </li>
#   <li>Generacion del reporte escritorio </li>
#   </ol>
#   <h3 Style = "color:#DC143C">¿Cual marca de carros tenemos mas en inventario?</h3>

# %%
dfAutos.head(3)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...    peak  City  Higway    price City L/100km  \
# 0    rwd  front  88.6  ...  5000.0    21      27  13495.0    11.190476
# 1    rwd  front  88.6  ...  5000.0    21      27  16500.0    11.190476
# 2    rwd  front  94.5  ...  5000.0    19      26  16500.0    12.368421
#
#   Higway L/100km  lengthNorm widthNorm  heingtNorm  horsepowerBins
# 0       8.703704    0.811148  0.890278    0.816054         Pequeño
# 1       8.703704    0.811148  0.890278    0.816054         Pequeño
# 2       9.038462    0.822681  0.909722    0.876254         Mediano
#
# [3 rows x 32 columns]

# %%
#Se agrupan y cuenta la cantidad de registros segun marca
dfGraf = dfAutos.groupby (["make"]). count()
#Se selecciona unicamente el indice y la primera columna
dfGraf = dfGraf.iloc[:,:1]
#Se ordenan los datos de mayor a menor
dfGraf =dfGraf.sort_values("symboling", ascending = False)
#Se muestra el DataFrame para graficar
dfGraf
# Out:
#                symboling
# make
# toyota                46
# volkswagen            24
# nissan                18
# mazda                 17
# mitsubishi            13
# honda                 13
# subaru                12
# peugot                11
# dodge                  9
# bmw                    8
# mercedes-benz          8
# plymouth               7
# saab                   6
# volvo                  6
# audi                   6
# porsche                4
# jaguar                 3
# chevrolet              3
# alfa-romero            3
# renault                2
# isuzu                  2
# mercury                1

# %%
fig,ax=plt.subplots(1,1,figsize=(11,6.9),dpi=100)
 
# Datos para crear el grafico
eje_x = dfGraf.index.tolist()
eje_y = dfGraf['symboling'].tolist()
y_pos = np.arange(len(eje_x))
 
#Generacion de colores para el grafico
bar_colors = ['#3cf378', '#fbd53f','#fbd53f','#fbd53f','#fbd53f','#fbd53f',
             '#fbd53f','#fbd53f', '#fbd53f', '#fbd53f', '#fbd53f', '#fbd53f',
             '#fbd53f', '#fbd53f', '#fbd53f', '#fbd53f', '#fbd53f', '#fbd53f',
             '#fbd53f','#fbd53f', '#fbd53f', '#ff974a']
 
#Creacion del grafico
ax.barh(y_pos, eje_y, align='center', color = bar_colors)
 
#Formato del grafico
#-------Titulo y Subtitulo del grafico
title_t = "Figura 1: Cantidad de Vehiculos"
ax.set_title(title_t,
             horizontalalignment = 'left',
             x=0.001,
             y=0.96,
             transform=fig.transFigure,
             fontsize=24,
             fontweight="bold",
             fontfamily="serif")
 
subtitle_t = 'Total de vehiculos agrupados segun marca o fabricante.'
plt.suptitle(subtitle_t,
            horizontalalignment = "left",
            x = 0.001,
            y = 0.94,
            transform = fig.transFigure,
            fontsize=16,
            fontweight="regular",
            fontfamily="serif")
 
#-------Etiquetas en Eje X y Y
label = "Cantidad"
ax.set_xlabel(label,
             ha="left",
             fontsize=10,
             fontweight="regular",
             fontfamily="sans")
 
ax.xaxis.set_label_coords(x=0,
                          y=-0.07,
                          transform=ax.transAxes)
 
ax.tick_params(axis='both',
               labelsize=12)
 
ax.set_yticks(y_pos, labels=eje_x)
ax.invert_yaxis()
plt.subplots_adjust(top=0.80)
 
plt.show()

# %% [markdown]
#   <h3 Style = "color:#DC143C">¿Cual es la distribucion de los autos segun estilo?</h3>

# %%
#Se agrupan y cuenta la cantidad de registros segun marca
dfGraf = dfAutos.groupby(["style"]).count()
#Se seleccionan unicamente el indice y la primera columna
dfGraf = dfGraf.iloc[:,:1]
#Se ordenan los datos de mayor a menor.
dfGraf = dfGraf.sort_values("symboling", ascending = False)
#Se muestra el DataFrame para graficar
dfGraf
# Out:
#              symboling
# style
# sedan              103
# hatchback           75
# wagon               26
# hardtop             10
# convertible          8

# %%
names = dfGraf.index.tolist()
style=dfGraf["symboling"].tolist()

circulo = plt.Circle((0,0), 0.7, color="white") #Este circulo es la base del grafico de anillos

plt.pie(style,
       labels=names,
       autopct="%1.1f%%",
       colors=["#3cf378", "#fbd53f", "#8b0074", "#eb0052", "#ff974a"])

p = plt.gcf()
p.gca().add_artist(circulo)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#   <h3 Style = "color:#DC143C">¿Cuantos autos existen en inventario segun la cantidad de cilindros?</h3>

# %%
dfGraf = dfAutos.groupby(["Cylinders"]).count()
dfGraf = dfGraf.iloc[:,:1]
dfGraf = dfGraf.sort_values("symboling", ascending = False)
dfGraf
# Out:
#            symboling
# Cylinders
# four             175
# six               26
# five              11
# eight              4
# two                4
# three              1
# twelve             1

# %%
fig,ax = plt.subplots(1,1, figsize =(11,6.9), dpi = 105) 

x1 = dfGraf.index.tolist()
y1 = dfGraf["symboling"].tolist()

bar_colors = ["#20dad4", "#7ae7ac", "#740a80", "#cb147c", "#cb147c", "#cb147c", "#f17f90"]

ax.bar(x1, y1, align = "center",  color = bar_colors)
#ax.set_yticks(y1, labels = x1)
#ax.invert_yaxis() #labels read top-to-bottom
ax.set_xlabel("cantidad")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#   <h3 Style = "color:#DC143C">¿Existe alguna relacion entre el estilo del auto y el precio?</h3>

# %%
dfGraf = dfAutos.groupby(["style", "price"]).count()
dfGraf = dfGraf.iloc[:,:1]
dfGraf = dfGraf.sort_values("symboling", ascending =False)
dfGraf
# Out:
#                      symboling
# style       price
# sedan       7775.0           3
#             8495.0           3
# convertible 11595.0          2
# sedan       12940.0          2
# hatchback   9988.0           2
# ...                        ...
#             14869.0          1
#             15040.0          1
#             15645.0          1
#             16500.0          1
# wagon       28248.0          1
#
# [183 rows x 1 columns]
